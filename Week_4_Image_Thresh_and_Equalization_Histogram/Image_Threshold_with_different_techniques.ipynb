# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
my_rgb_img = cv2.imread("./tavus.jpg",1)
my_gray_img = cv2.cvtColor(my_rgb_img, cv2.COLOR_BGR2GRAY)

# %%
_, my_thresh_binary = cv2.threshold(my_gray_img, thresh = 128, maxval = 255, type = cv2.THRESH_BINARY)

# %%
cv2.imshow("RGB", my_rgb_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("GRAY", my_gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("thresh", my_thresh_binary)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
fig = plt.figure(figsize = (10, 7))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(my_gray_img, cmap = "gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns, 2)
plt.imshow(my_thresh_binary, cmap = "gray")
plt.axis('off')
plt.title("BINARY THRESHOLDİNG IMAGE")
# Out:
# Text(0.5, 1.0, 'BINARY THRESHOLDİNG IMAGE')

# %%
my_gray_img
# Out:
# array([[ 48,  75,  81, ...,  58,  59,  58],
#        [151,  97,  71, ...,  52,  50,  47],
#        [154, 127, 112, ...,  47,  41,  36],
#        ...,
#        [ 48,  38,  39, ...,  71,  81, 106],
#        [ 35,  30,  44, ...,  55,  73, 116],
#        [ 36,  31,  32, ...,  40,  47,  88]], dtype=uint8)

# %%
_, my_thresh_binary_inv = cv2.threshold(my_gray_img, thresh = 128, maxval = 255, type = cv2.THRESH_BINARY_INV)

# %%
fig = plt.figure(figsize = (10, 7))
rows = 1
columns = 3

fig.add_subplot(rows, columns, 1)
plt.imshow(my_gray_img, cmap = "gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns, 2)
plt.imshow(my_thresh_binary, cmap = "gray")
plt.axis('off')
plt.title("BINARY THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 3)
plt.imshow(my_thresh_binary_inv, cmap = "gray")
plt.axis('off')
plt.title("BINARY INV THRESHOLDİNG IMAGE")
# Out:
# Text(0.5, 1.0, 'BINARY INV THRESHOLDİNG IMAGE')

# %%
_, my_thresh_trunc = cv2.threshold(my_gray_img, thresh = 128, maxval = 255, type = cv2.THRESH_TRUNC)

# %%
fig = plt.figure(figsize = (10, 7))
rows = 2
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(my_gray_img, cmap = "gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns, 2)
plt.imshow(my_thresh_binary, cmap = "gray")
plt.axis('off')
plt.title("BINARY THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 3)
plt.imshow(my_thresh_binary_inv, cmap = "gray")
plt.axis('off')
plt.title("BINARY INV THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 4)
plt.imshow(my_thresh_trunc, cmap = "gray")
plt.axis('off')
plt.title("TRUNC THRESHOLDİNG IMAGE")
# Out:
# Text(0.5, 1.0, 'TRUNC THRESHOLDİNG IMAGE')

# %%
_, my_thresh_tozero = cv2.threshold(my_gray_img, thresh = 128, maxval = 255, type = cv2.THRESH_TOZERO)

# %%
fig = plt.figure(figsize = (10, 7))
rows = 2
columns = 3

fig.add_subplot(rows, columns, 1)
plt.imshow(my_gray_img, cmap = "gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns, 2)
plt.imshow(my_thresh_binary, cmap = "gray")
plt.axis('off')
plt.title("BINARY THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 3)
plt.imshow(my_thresh_binary_inv, cmap = "gray")
plt.axis('off')
plt.title("BINARY INV THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 4)
plt.imshow(my_thresh_trunc, cmap = "gray")
plt.axis('off')
plt.title("TRUNC THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 5)
plt.imshow(my_thresh_tozero, cmap = "gray")
plt.axis('off')
plt.title("Tozero THRESHOLDİNG IMAGE")
# Out:
# Text(0.5, 1.0, 'Tozero THRESHOLDİNG IMAGE')

# %%
_, my_thresh_tozero_inv = cv2.threshold(my_gray_img, thresh = 128, maxval = 255, type = cv2.THRESH_TOZERO_INV)

# %%
fig = plt.figure(figsize = (10, 7))
rows = 3
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(my_gray_img, cmap = "gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns, 2)
plt.imshow(my_thresh_binary, cmap = "gray")
plt.axis('off')
plt.title("BINARY THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 3)
plt.imshow(my_thresh_binary_inv, cmap = "gray")
plt.axis('off')
plt.title("BINARY INV THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 4)
plt.imshow(my_thresh_trunc, cmap = "gray")
plt.axis('off')
plt.title("TRUNC THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 5)
plt.imshow(my_thresh_tozero, cmap = "gray")
plt.axis('off')
plt.title("TOZERO THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 6)
plt.imshow(my_thresh_tozero_inv, cmap = "gray")
plt.axis('off')
plt.title("TOZERO INV THRESHOLDİNG IMAGE")
# Out:
# Text(0.5, 1.0, 'TOZERO INV THRESHOLDİNG IMAGE')

# %%
fig = plt.figure(figsize = (10, 7))
rows = 3
columns = 2

fig.add_subplot(rows, columns, 1)
plt.imshow(my_gray_img, cmap = "gray")
plt.axis('off')
plt.title("Original Image")

fig.add_subplot(rows, columns, 2)
plt.imshow(my_thresh_binary, cmap = "gray")
plt.axis('off')
plt.title("BINARY THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 3)
plt.imshow(my_thresh_binary_inv, cmap = "gray")
plt.axis('off')
plt.title("BINARY INV THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 4)
plt.imshow(my_thresh_trunc, cmap = "gray")
plt.axis('off')
plt.title("TRUNC THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 5)
plt.imshow(my_thresh_tozero, cmap = "gray")
plt.axis('off')
plt.title("TOZERO THRESHOLDİNG IMAGE")

fig.add_subplot(rows, columns, 6)
plt.imshow(my_thresh_tozero_inv, cmap = "gray")
plt.axis('off')
plt.title("TOZERO INV THRESHOLDİNG IMAGE")

plt.tight_layout()
plt.savefig("./my_all_threshold_techniques.png", dpi = 300)
plt.show()
